# %%
import pandas as pd

# %% [markdown]
# # Loading and Preprocessing Data

# %% [markdown]
# ## Station Data

# %% [markdown]
# The station data can be used as-is, but we will be limiting our analysis to Boston proper.

# %%
stations = pd.read_csv('data/bluebikes/current_bluebikes_stations.csv', skiprows=1)
stations
# Out:
#      Number                                 Name   Latitude  Longitude  \
# 0    K32015                       1200 Beacon St  42.344149 -71.114674
# 1    W32006                       160 Arsenal St  42.364664 -71.175694
# 2    A32019                     175 N Harvard St  42.364475 -71.128408
# 3    S32035                        191 Beacon St  42.380323 -71.108786
# 4    C32094  2 Hummingbird Lane at Olmsted Green  42.288870 -71.095003
# ..      ...                                  ...        ...        ...
# 416  D32022                        West End Park  42.365908 -71.064467
# 417  N32005                          West Newton  42.349601 -71.226275
# 418  B32059            Whittier St Health Center  42.332863 -71.092189
# 419  D32040         Williams St at Washington St  42.306539 -71.107669
# 420  S32005                        Wilson Square  42.385676 -71.114121
#
#        District Public  Total docks
# 0     Brookline    Yes           15
# 1     Watertown    Yes           11
# 2        Boston    Yes           17
# 3    Somerville    Yes           19
# 4        Boston    Yes           17
# ..          ...    ...          ...
# 416      Boston    Yes           35
# 417      Newton    Yes           15
# 418      Boston    Yes           19
# 419      Boston    Yes           23
# 420  Somerville    Yes           15
#
# [421 rows x 7 columns]

# %%
boston_stations = stations.loc[stations['District'] == 'Boston'].drop(columns=['District']).reset_index(drop=True)
boston_stations
# Out:
#      Number                                               Name   Latitude  \
# 0    A32019                                   175 N Harvard St  42.364475
# 1    C32094                2 Hummingbird Lane at Olmsted Green  42.288870
# 2    C32106                               555 Metropolitan Ave  42.268100
# 3    C32105           606 American Legion Hwy at Canterbury St  42.285780
# 4    C32091                                      645 Summer St  42.341781
# ..      ...                                                ...        ...
# 208  C32034  Watermark Seaport - Boston Wharf Rd at Seaport...  42.351586
# 209  B32021  Wentworth Institute of Technology - Huntington...  42.337586
# 210  D32022                                      West End Park  42.365908
# 211  B32059                          Whittier St Health Center  42.332863
# 212  D32040                       Williams St at Washington St  42.306539
#
#      Longitude Public  Total docks
# 0   -71.128408    Yes           17
# 1   -71.095003    Yes           17
# 2   -71.119240    Yes           18
# 3   -71.109725    Yes           18
# 4   -71.039870    Yes           19
# ..         ...    ...          ...
# 208 -71.045693    Yes           15
# 209 -71.096271    Yes           12
# 210 -71.064467    Yes           35
# 211 -71.092189    Yes           19
# 212 -71.107669    Yes           23
#
# [213 rows x 6 columns]

# %%
boston_stations.to_csv('data/bluebikes/current_bluebikes_stations_boston.csv', index=False)

# %% [markdown]
# ## Trip Data

# %% [markdown]
# The columns are different across different months...

# %%
trips = []
trip_columns = []
for y in range(2015, 2025):
    for m in range(1, 13):
        mo = '0' + str(m) if m < 10 else str(m)
        stem = str(y) + mo
        if stem == '202402':
            break
        trip = pd.read_csv(f'data/bluebikes/trips_raw/{stem}-bluebikes-tripdata.csv')
        trips.append(trip)
        trip_columns.append(list(trip.columns))

# %% [markdown]
# Let's see when the columns change

# %%
differences = [0]
for i in range(len(trip_columns) - 1):
    if trip_columns[i] != trip_columns[i + 1]:
        print(f'Datasets at indices {i} and {i+1} have different columns!')
        differences.append(i+1)
# Out:
# Datasets at indices 63 and 64 have different columns!
# Datasets at indices 98 and 99 have different columns!

# %% [markdown]
# Luckily, there appear to only be three different sets of columns. Let's look at them

# %%
for d in differences:
    display(trips[d].head())
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           542  2015-01-01 00:21:44  2015-01-01 00:30:47               115
# 1           438  2015-01-01 00:27:03  2015-01-01 00:34:21                80
# 2           254  2015-01-01 00:31:31  2015-01-01 00:35:46                91
# 3           432  2015-01-01 00:53:46  2015-01-01 01:00:58               115
# 4           735  2015-01-01 01:07:06  2015-01-01 01:19:21               105
#
#                                  start station name  start station latitude  \
# 0                             Porter Square Station               42.387995
# 1           MIT Stata Center at Vassar St / Main St               42.361962
# 2  One Kendall Square at Hampshire St / Portland St               42.366277
# 3                             Porter Square Station               42.387995
# 4   Lower Cambridgeport at Magazine St/Riverside Rd               42.356954
#
#    start station longitude  end station id  \
# 0               -71.119084              96
# 1               -71.092053              95
# 2               -71.091690              68
# 3               -71.119084              96
# 4               -71.113687              88
#
#                                     end station name  end station latitude  \
# 0  Cambridge Main Library at Broadway / Trowbridg...             42.373379
# 1        Cambridge St - at Columbia St / Webster Ave             42.372969
# 2              Central Square at Mass Ave / Essex St             42.365070
# 3  Cambridge Main Library at Broadway / Trowbridg...             42.373379
# 4      Inman Square at Vellucci Plaza / Hampshire St             42.374035
#
#    end station longitude  bikeid    usertype birth year  gender
# 0             -71.111075     277  Subscriber       1984       1
# 1             -71.094445     648  Subscriber       1985       1
# 2             -71.103100     555  Subscriber       1974       1
# 3             -71.111075    1307  Subscriber       1987       1
# 4             -71.101427     177    Customer       1986       2
#    tripduration                 starttime                  stoptime  \
# 0          1577  2020-05-01 00:03:09.7400  2020-05-01 00:29:26.9630
# 1           943  2020-05-01 00:04:13.1380  2020-05-01 00:19:56.3460
# 2          1521  2020-05-01 00:11:00.0640  2020-05-01 00:36:21.5300
# 3           891  2020-05-01 00:11:20.6610  2020-05-01 00:26:12.6180
# 4           439  2020-05-01 00:28:07.6160  2020-05-01 00:35:27.2910
#
#    start station id                          start station name  \
# 0                74         Harvard Square at Mass Ave/ Dunster
# 1                67                MIT at Mass Ave / Amherst St
# 2                80     MIT Stata Center at Vassar St / Main St
# 3               205                     Bowdoin St at Quincy St
# 4                86  Brookline Village - Station Street at MBTA
#
#    start station latitude  start station longitude  end station id  \
# 0               42.373268               -71.118579              97
# 1               42.358100               -71.093198               5
# 2               42.362131               -71.091156             344
# 3               42.307852               -71.065122             445
# 4               42.332744               -71.116267             103
#
#                                     end station name  end station latitude  \
# 0  Harvard University River Houses at DeWolfe St ...             42.369190
# 1        Northeastern University - North Parking Lot             42.341814
# 2                    Commonwealth Ave at Chiswick Rd             42.340246
# 3              Geiger Gibson Community Health Center             42.318865
# 4        JFK Crossing at Harvard St. / Thorndike St.             42.346563
#
#    end station longitude  bikeid    usertype postal code
# 0             -71.117141    3941    Customer         NaN
# 1             -71.090179    4469  Subscriber       02120
# 2             -71.151688    3703  Subscriber       02135
# 3             -71.045368    3726  Subscriber       02125
# 4             -71.128374    4862  Subscriber       02143
#             ride_id rideable_type           started_at             ended_at  \
# 0  0093AA5E7E3E0158   docked_bike  2023-04-13 13:49:59  2023-04-13 13:55:04
# 1  BFA8B88E063688F4   docked_bike  2023-04-25 09:44:38  2023-04-25 09:51:28
# 2  A9C51FA200C31A81   docked_bike  2023-04-24 18:39:31  2023-04-24 18:58:05
# 3  0C1D451797FF0871   docked_bike  2023-04-04 19:25:31  2023-04-04 19:32:14
# 4  DDDCD0A2D2EE7A37   docked_bike  2023-04-11 08:36:14  2023-04-11 08:52:39
#
#                                start_station_name start_station_id  \
# 0  Innovation Lab - 125 Western Ave at Batten Way           A32011
# 1                               Museum of Science           M32045
# 2                       New Balance - 20 Guest St           D32001
# 3                               Museum of Science           M32045
# 4                               Museum of Science           M32045
#
#                                   end_station_name end_station_id  start_lat  \
# 0            Soldiers Field Park - 111 Western Ave         A32006  42.363713
# 1    One Broadway / Kendall Sq at Main St / 3rd St         M32003  42.367690
# 2  HMS/HSPH - Avenue Louis Pasteur at Longwood Ave         B32003  42.357329
# 3                    Gore Street at Lambert Street         M32081  42.367690
# 4                     Columbus Ave at W. Canton St         C32077  42.367690
#
#    start_lng    end_lat    end_lng member_casual
# 0 -71.124598  42.364263 -71.118276        member
# 1 -71.071163  42.362242 -71.083111        member
# 2 -71.146735  42.337417 -71.102861        casual
# 3 -71.071163  42.373080 -71.086342        member
# 4 -71.071163  42.344742 -71.076482        member

# %% [markdown]
# The differences between the first and second sets are that the first contains the users' birth year and gender, while the second one contains the postal code instead. There are major differences between the second and third sets, but some of the columns provide the same information while being named differently.
#
# We'll combine the datasets using the first two sets of column names (because they are almost identical) and rename the columns to match the third set of column names.

# %%
trips_combined_1 = pd.concat(trips[differences[0]:differences[2] - 1]).rename(columns={
    'starttime': 'started_at',
    'stoptime': 'ended_at',
    'tripduration': 'duration',
    'start station id': 'start_station_id_old',
    'start station name': 'start_station_name',
    'start station latitude': 'start_lat',
    'start station longitude': 'start_lng',
    'end station id': 'end_station_id_old',
    'end station name': 'end_station_name',
    'end station latitude': 'end_lat',
    'end station longitude': 'end_lng'
})
for c in ['started_at', 'ended_at']:
    trips_combined_1[c] = pd.to_datetime(trips_combined_1[c])
trips_combined_1['usertype'] = trips_combined_1['usertype'].apply(lambda s: 'member' if s == 'Subscriber' else 'casual')
trips_combined_1
# Out:
#         duration              started_at                ended_at  \
# 0            542 2015-01-01 00:21:44.000 2015-01-01 00:30:47.000
# 1            438 2015-01-01 00:27:03.000 2015-01-01 00:34:21.000
# 2            254 2015-01-01 00:31:31.000 2015-01-01 00:35:46.000
# 3            432 2015-01-01 00:53:46.000 2015-01-01 01:00:58.000
# 4            735 2015-01-01 01:07:06.000 2015-01-01 01:19:21.000
# ...          ...                     ...                     ...
# 152970       417 2023-02-28 23:57:36.922 2023-03-01 00:04:34.583
# 152971       872 2023-02-28 23:58:06.895 2023-03-01 00:12:39.341
# 152972       384 2023-02-28 23:58:20.949 2023-03-01 00:04:45.218
# 152973       593 2023-02-28 23:58:36.547 2023-03-01 00:08:29.656
# 152974       532 2023-02-28 23:59:50.821 2023-03-01 00:08:43.802
#
#         start_station_id_old  \
# 0                        115
# 1                         80
# 2                         91
# 3                        115
# 4                        105
# ...                      ...
# 152970                    46
# 152971                    11
# 152972                   553
# 152973                    36
# 152974                    36
#
#                                        start_station_name  start_lat  \
# 0                                   Porter Square Station  42.387995
# 1                 MIT Stata Center at Vassar St / Main St  42.361962
# 2        One Kendall Square at Hampshire St / Portland St  42.366277
# 3                                   Porter Square Station  42.387995
# 4         Lower Cambridgeport at Magazine St/Riverside Rd  42.356954
# ...                                                   ...        ...
# 152970  Christian Science Plaza - Massachusetts Ave at...  42.343666
# 152971                          Longwood Ave at Binney St  42.338629
# 152972           Cambridge Crossing at North First Street  42.371141
# 152973        Copley Square - Dartmouth St at Boylston St  42.349928
# 152974        Copley Square - Dartmouth St at Boylston St  42.349928
#
#         start_lng end_station_id_old  \
# 0      -71.119084                 96
# 1      -71.092053                 95
# 2      -71.091690                 68
# 3      -71.119084                 96
# 4      -71.113687                 88
# ...           ...                ...
# 152970 -71.085824                331
# 152971 -71.106500                491
# 152972 -71.076198                413
# 152973 -71.077392                152
# 152974 -71.077392                152
#
#                                          end_station_name    end_lat  \
# 0       Cambridge Main Library at Broadway / Trowbridg...  42.373379
# 1             Cambridge St - at Columbia St / Webster Ave  42.372969
# 2                   Central Square at Mass Ave / Essex St   42.36507
# 3       Cambridge Main Library at Broadway / Trowbridg...  42.373379
# 4           Inman Square at Vellucci Plaza / Hampshire St  42.374035
# ...                                                   ...        ...
# 152970                         Huntington Ave at Mass Art  42.336586
# 152971                       Harrison Ave at E. Dedham St  42.339194
# 152972            Kennedy-Longfellow School 158 Spring St  42.369553
# 152973              Ink Block - Harrison Ave at Herald St  42.345901
# 152974              Ink Block - Harrison Ave at Herald St  42.345901
#
#           end_lng  bikeid usertype birth year  gender postal code
# 0      -71.111075     277   member       1984     1.0         NaN
# 1      -71.094445     648   member       1985     1.0         NaN
# 2        -71.1031     555   member       1974     1.0         NaN
# 3      -71.111075    1307   member       1987     1.0         NaN
# 4      -71.101427     177   casual       1986     2.0         NaN
# ...           ...     ...      ...        ...     ...         ...
# 152970  -71.09887    3442   member        NaN     NaN       02120
# 152971  -71.06975    2876   member        NaN     NaN       02446
# 152972  -71.08579    6349   member        NaN     NaN       02141
# 152973 -71.063187    8277   member        NaN     NaN       33332
# 152974 -71.063187    7801   casual        NaN     NaN       28584
#
# [17021534 rows x 16 columns]

# %%
trips_combined_2 = pd.concat(trips[differences[2]:]).rename(columns={
    'start_station_id': 'start_station_id_new',
    'end_station_id': 'end_station_id_new'
})
for c in ['started_at', 'ended_at']:
    trips_combined_2[c] = pd.to_datetime(trips_combined_2[c])
trips_combined_2['duration'] = (pd.to_numeric(trips_combined_2['ended_at'] - trips_combined_2['started_at']) / 10e8).astype(int)
trips_combined_2
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       0093AA5E7E3E0158    docked_bike 2023-04-13 13:49:59
# 1       BFA8B88E063688F4    docked_bike 2023-04-25 09:44:38
# 2       A9C51FA200C31A81    docked_bike 2023-04-24 18:39:31
# 3       0C1D451797FF0871    docked_bike 2023-04-04 19:25:31
# 4       DDDCD0A2D2EE7A37    docked_bike 2023-04-11 08:36:14
# ...                  ...            ...                 ...
# 166694  C77DAA204E19EF6A   classic_bike 2024-01-13 12:10:36
# 166695  77BC9B9BCAD3EBA6   classic_bike 2024-01-27 12:08:39
# 166696  C24A84547C47B792  electric_bike 2024-01-23 19:13:05
# 166697  179B600DC22C66D7   classic_bike 2024-01-11 16:41:42
# 166698  0C09D09DCF1171F1   classic_bike 2024-01-27 00:12:18
#
#                   ended_at                                 start_station_name  \
# 0      2023-04-13 13:55:04     Innovation Lab - 125 Western Ave at Batten Way
# 1      2023-04-25 09:51:28                                  Museum of Science
# 2      2023-04-24 18:58:05                          New Balance - 20 Guest St
# 3      2023-04-04 19:32:14                                  Museum of Science
# 4      2023-04-11 08:52:39                                  Museum of Science
# ...                    ...                                                ...
# 166694 2024-01-13 12:42:42  Newmarket Square T Stop - Massachusetts Ave at...
# 166695 2024-01-27 12:45:33  Newmarket Square T Stop - Massachusetts Ave at...
# 166696 2024-01-23 19:20:42                 Aquarium T Stop - 200 Atlantic Ave
# 166697 2024-01-11 17:12:00                                  55 Wheeler Street
# 166698 2024-01-27 00:31:28                 Aquarium T Stop - 200 Atlantic Ave
#
#        start_station_id_new                                 end_station_name  \
# 0                    A32011            Soldiers Field Park - 111 Western Ave
# 1                    M32045    One Broadway / Kendall Sq at Main St / 3rd St
# 2                    D32001  HMS/HSPH - Avenue Louis Pasteur at Longwood Ave
# 3                    M32045                    Gore Street at Lambert Street
# 4                    M32045                     Columbus Ave at W. Canton St
# ...                     ...                                              ...
# 166694               C32022                       Somerville City Hall Annex
# 166695               C32022                       Somerville City Hall Annex
# 166696               B32004                           Main St at Thompson Sq
# 166697               M32088                       Somerville City Hall Annex
# 166698               B32004                           Main St at Thompson Sq
#
#        end_station_id_new  start_lat  start_lng    end_lat    end_lng  \
# 0                  A32006  42.363713 -71.124598  42.364263 -71.118276
# 1                  M32003  42.367690 -71.071163  42.362242 -71.083111
# 2                  B32003  42.357329 -71.146735  42.337417 -71.102861
# 3                  M32081  42.367690 -71.071163  42.373080 -71.086342
# 4                  C32077  42.367690 -71.071163  42.344742 -71.076482
# ...                   ...        ...        ...        ...        ...
# 166694             S32036  42.326599 -71.066498  42.391898 -71.097454
# 166695             S32036  42.326599 -71.066498  42.391898 -71.097454
# 166696             D32038  42.360479 -71.050593  42.374878 -71.063835
# 166697             S32036  42.390821 -71.143946  42.391898 -71.097454
# 166698             D32038  42.360441 -71.050439  42.374878 -71.063835
#
#        member_casual  duration
# 0             member       305
# 1             member       410
# 2             casual      1114
# 3             member       403
# 4             member       985
# ...              ...       ...
# 166694        member      1926
# 166695        member      2214
# 166696        member       457
# 166697        member      1818
# 166698        casual      1150
#
# [3367574 rows x 14 columns]

# %%
trips_combined = pd.concat([trips_combined_1, trips_combined_2], ignore_index=True)
trips_combined = trips_combined.loc[(trips_combined['start_station_name'].isin(boston_stations)) | (trips_combined['end_station_name'].isin(boston_stations))]
trips_combined
# Out:
#           duration          started_at            ended_at  \
# 89             413 2015-01-01 16:19:32 2015-01-01 16:26:26
# 137            575 2015-01-02 08:06:49 2015-01-02 08:16:25
# 190            886 2015-01-02 11:38:38 2015-01-02 11:53:24
# 216           1027 2015-01-02 13:33:05 2015-01-02 13:50:12
# 722            383 2015-01-05 10:15:46 2015-01-05 10:22:09
# ...            ...                 ...                 ...
# 20389102       312 2024-01-12 15:38:53 2024-01-12 15:44:05
# 20389103      1926 2024-01-13 12:10:36 2024-01-13 12:42:42
# 20389104      2214 2024-01-27 12:08:39 2024-01-27 12:45:33
# 20389105       457 2024-01-23 19:13:05 2024-01-23 19:20:42
# 20389107      1150 2024-01-27 00:12:18 2024-01-27 00:31:28
#
#           start_station_id_old  \
# 89                       143.0
# 137                       90.0
# 190                       95.0
# 216                       91.0
# 722                      143.0
# ...                        ...
# 20389102                   NaN
# 20389103                   NaN
# 20389104                   NaN
# 20389105                   NaN
# 20389107                   NaN
#
#                                          start_station_name  start_lat  \
# 89                                    EF - North Point Park  42.369885
# 137             Lechmere Station at Cambridge St / First St  42.370677
# 190             Cambridge St - at Columbia St / Webster Ave  42.372969
# 216        One Kendall Square at Hampshire St / Portland St  42.366277
# 722                                   EF - North Point Park  42.369885
# ...                                                     ...        ...
# 20389102                              Charlestown Navy Yard  42.374125
# 20389103  Newmarket Square T Stop - Massachusetts Ave at...  42.326599
# 20389104  Newmarket Square T Stop - Massachusetts Ave at...  42.326599
# 20389105                 Aquarium T Stop - 200 Atlantic Ave  42.360479
# 20389107                 Aquarium T Stop - 200 Atlantic Ave  42.360441
#
#           start_lng end_station_id_old  \
# 89       -71.069957                 85
# 137      -71.076529                 85
# 190      -71.094445                 85
# 216      -71.091690                 85
# 722      -71.069957                 85
# ...             ...                ...
# 20389102 -71.054812                NaN
# 20389103 -71.066498                NaN
# 20389104 -71.066498                NaN
# 20389105 -71.050593                NaN
# 20389107 -71.050439                NaN
#
#                                            end_station_name    end_lat  ...  \
# 89        Spaulding Rehabilitation Hospital - Charlestow...  42.378338  ...
# 137       Spaulding Rehabilitation Hospital - Charlestow...  42.378338  ...
# 190       Spaulding Rehabilitation Hospital - Charlestow...  42.378338  ...
# 216       Spaulding Rehabilitation Hospital - Charlestow...  42.378338  ...
# 722       Spaulding Rehabilitation Hospital - Charlestow...  42.378338  ...
# ...                                                     ...        ...  ...
# 20389102                             Main St at Thompson Sq  42.374878  ...
# 20389103                         Somerville City Hall Annex  42.391898  ...
# 20389104                         Somerville City Hall Annex  42.391898  ...
# 20389105                             Main St at Thompson Sq  42.374878  ...
# 20389107                             Main St at Thompson Sq  42.374878  ...
#
#           bikeid  usertype birth year gender  postal code           ride_id  \
# 89         481.0    member       1983    1.0          NaN               NaN
# 137       1295.0    member       1983    1.0          NaN               NaN
# 190        652.0    casual       1992    2.0          NaN               NaN
# 216       1094.0    member       1983    1.0          NaN               NaN
# 722        761.0    member       1983    1.0          NaN               NaN
# ...          ...       ...        ...    ...          ...               ...
# 20389102     NaN       NaN        NaN    NaN          NaN  BA5F71F2B4F60857
# 20389103     NaN       NaN        NaN    NaN          NaN  C77DAA204E19EF6A
# 20389104     NaN       NaN        NaN    NaN          NaN  77BC9B9BCAD3EBA6
# 20389105     NaN       NaN        NaN    NaN          NaN  C24A84547C47B792
# 20389107     NaN       NaN        NaN    NaN          NaN  0C09D09DCF1171F1
#
#           rideable_type start_station_id_new end_station_id_new member_casual
# 89                  NaN                  NaN                NaN           NaN
# 137                 NaN                  NaN                NaN           NaN
# 190                 NaN                  NaN                NaN           NaN
# 216                 NaN                  NaN                NaN           NaN
# 722                 NaN                  NaN                NaN           NaN
# ...                 ...                  ...                ...           ...
# 20389102   classic_bike               D32039             D32038        member
# 20389103   classic_bike               C32022             S32036        member
# 20389104   classic_bike               C32022             S32036        member
# 20389105  electric_bike               B32004             D32038        member
# 20389107   classic_bike               B32004             D32038        casual
#
# [11616984 rows x 21 columns]

# %%
trips_combined.reset_index(inplace=True, drop=True)
chunksize = 500000
c = 1
for i in range(0, len(trips_combined), chunksize):
    trips_combined.iloc[i:i + chunksize].to_pickle(f'data/bluebikes/trips_combined_boston/{c}.pkl')
    c += 1
trips_combined
# Out:
#           duration          started_at            ended_at  \
# 0              413 2015-01-01 16:19:32 2015-01-01 16:26:26
# 1              575 2015-01-02 08:06:49 2015-01-02 08:16:25
# 2              886 2015-01-02 11:38:38 2015-01-02 11:53:24
# 3             1027 2015-01-02 13:33:05 2015-01-02 13:50:12
# 4              383 2015-01-05 10:15:46 2015-01-05 10:22:09
# ...            ...                 ...                 ...
# 11616979       312 2024-01-12 15:38:53 2024-01-12 15:44:05
# 11616980      1926 2024-01-13 12:10:36 2024-01-13 12:42:42
# 11616981      2214 2024-01-27 12:08:39 2024-01-27 12:45:33
# 11616982       457 2024-01-23 19:13:05 2024-01-23 19:20:42
# 11616983      1150 2024-01-27 00:12:18 2024-01-27 00:31:28
#
#           start_station_id_old  \
# 0                        143.0
# 1                         90.0
# 2                         95.0
# 3                         91.0
# 4                        143.0
# ...                        ...
# 11616979                   NaN
# 11616980                   NaN
# 11616981                   NaN
# 11616982                   NaN
# 11616983                   NaN
#
#                                          start_station_name  start_lat  \
# 0                                     EF - North Point Park  42.369885
# 1               Lechmere Station at Cambridge St / First St  42.370677
# 2               Cambridge St - at Columbia St / Webster Ave  42.372969
# 3          One Kendall Square at Hampshire St / Portland St  42.366277
# 4                                     EF - North Point Park  42.369885
# ...                                                     ...        ...
# 11616979                              Charlestown Navy Yard  42.374125
# 11616980  Newmarket Square T Stop - Massachusetts Ave at...  42.326599
# 11616981  Newmarket Square T Stop - Massachusetts Ave at...  42.326599
# 11616982                 Aquarium T Stop - 200 Atlantic Ave  42.360479
# 11616983                 Aquarium T Stop - 200 Atlantic Ave  42.360441
#
#           start_lng end_station_id_old  \
# 0        -71.069957                 85
# 1        -71.076529                 85
# 2        -71.094445                 85
# 3        -71.091690                 85
# 4        -71.069957                 85
# ...             ...                ...
# 11616979 -71.054812                NaN
# 11616980 -71.066498                NaN
# 11616981 -71.066498                NaN
# 11616982 -71.050593                NaN
# 11616983 -71.050439                NaN
#
#                                            end_station_name    end_lat  ...  \
# 0         Spaulding Rehabilitation Hospital - Charlestow...  42.378338  ...
# 1         Spaulding Rehabilitation Hospital - Charlestow...  42.378338  ...
# 2         Spaulding Rehabilitation Hospital - Charlestow...  42.378338  ...
# 3         Spaulding Rehabilitation Hospital - Charlestow...  42.378338  ...
# 4         Spaulding Rehabilitation Hospital - Charlestow...  42.378338  ...
# ...                                                     ...        ...  ...
# 11616979                             Main St at Thompson Sq  42.374878  ...
# 11616980                         Somerville City Hall Annex  42.391898  ...
# 11616981                         Somerville City Hall Annex  42.391898  ...
# 11616982                             Main St at Thompson Sq  42.374878  ...
# 11616983                             Main St at Thompson Sq  42.374878  ...
#
#           bikeid  usertype birth year gender  postal code           ride_id  \
# 0          481.0    member       1983    1.0          NaN               NaN
# 1         1295.0    member       1983    1.0          NaN               NaN
# 2          652.0    casual       1992    2.0          NaN               NaN
# 3         1094.0    member       1983    1.0          NaN               NaN
# 4          761.0    member       1983    1.0          NaN               NaN
# ...          ...       ...        ...    ...          ...               ...
# 11616979     NaN       NaN        NaN    NaN          NaN  BA5F71F2B4F60857
# 11616980     NaN       NaN        NaN    NaN          NaN  C77DAA204E19EF6A
# 11616981     NaN       NaN        NaN    NaN          NaN  77BC9B9BCAD3EBA6
# 11616982     NaN       NaN        NaN    NaN          NaN  C24A84547C47B792
# 11616983     NaN       NaN        NaN    NaN          NaN  0C09D09DCF1171F1
#
#           rideable_type start_station_id_new end_station_id_new member_casual
# 0                   NaN                  NaN                NaN           NaN
# 1                   NaN                  NaN                NaN           NaN
# 2                   NaN                  NaN                NaN           NaN
# 3                   NaN                  NaN                NaN           NaN
# 4                   NaN                  NaN                NaN           NaN
# ...                 ...                  ...                ...           ...
# 11616979   classic_bike               D32039             D32038        member
# 11616980   classic_bike               C32022             S32036        member
# 11616981   classic_bike               C32022             S32036        member
# 11616982  electric_bike               B32004             D32038        member
# 11616983   classic_bike               B32004             D32038        casual
#
# [11616984 rows x 21 columns]
