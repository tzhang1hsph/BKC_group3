# %%
import pandas as pd
import plotly.express as px
px.set_mapbox_access_token(open(".mapbox_token").read())
import plotly.io as pio
pio.renderers.default = "notebook"

# %%
street_trees = pd.read_csv('data/locations/raw/street_trees.csv')
street_trees
# Out:
#                X          Y     id               spp_com  \
# 0     -71.064620  42.296120      2         Maple, Norway
# 1     -71.068880  42.343266      3                Ginkgo
# 2     -71.108800  42.286316      4      Oak, Swamp White
# 3     -71.087240  42.340870      5         Elm, American
# 4     -71.040200  42.365784      6      Sweetgum, Common
# ...          ...        ...    ...                   ...
# 43324 -71.079637  42.320608  43477                   Elm
# 43325 -71.046253  42.330863  43478       Cherry, Sargent
# 43326 -71.048301  42.334364  43479                   Elm
# 43327 -71.038331  42.336412  43480  Lilac, Japanese Tree
# 43328 -71.064143  42.380423  43481        Crabapple spp.
#
#                        spp_bot  numberof_st dbh_range  dbh date_plant    city  \
# 0             Acer platanoides            1     3-6in    5         --  Boston
# 1                Ginkgo biloba            1    6-12in   11         --  Boston
# ...

# %%
fig = px.scatter_mapbox(street_trees, lat='Y', lon='X', opacity=0.6,
                        center={'lat': 42.312, "lon": -71.0902}, zoom=11, width=1080, height=720)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <div>                            <div id="8247a308-91d6-45c6-8a0c-b3992a2a5cd2" class="plotly-graph-div" style="height:720px; width:1080px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8247a308-91d6-45c6-8a0c-b3992a2a5cd2")) {                    Plotly.newPlot(                        "8247a308-91d6-45c6-8a0c-b3992a2a5cd2",                        [{"hovertemplate":"Y=%{lat}<br>X=%{lon}<extra></extra>","lat":[42.29612,42.343266,42.286316,42.34087,42.365784,42.376305,42.344673,42.339195,42.36576,42.34079,42.339745,42.343613,42.27725,42.343204,42.340828,42.340748,42.339108,42.340347,42.34678,42.280037,42.37632,42.27473,42.278606,42.338913,42.323555,42.287254,42.35666,42.34059,42.338856,42.30421,42.379513,42.33995,42.347157,42.37598,42.346684,42.335007,42.34707,42.341873,42.35241,42.37676,42.34282,42.338802,
# ...
